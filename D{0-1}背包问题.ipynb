# %%
print("欢迎来到D{0-1}背包问题！")
#读取文件
name=input("请输入所需处理的文件名：")
if name == "idkp1-10":
    print("成功打开idkp1-10.txt文件") 
    data1=[]
    f1 = open(r'C:\Users\糖果布丁\Desktop\实验二 任务3data_set\实验二 任务3data_set\idkp1-10.txt')               # 返回一个文件对象   
    String=f1.read().strip().split('\n')
    for n in String:
        n.rstrip(',')
        n.rstrip('\n')
        n.rstrip('.')
        if n.startswith('*') or n.startswith('The') or n.startswith('IDKP') or n==''  :
            continue
        else:
            data1.append(n[:-1])
    print(data1)
    draw(data1)
    f1.close()
else:
    data2=[]
    f2 = open(r'C:\Users\糖果布丁\Desktop\实验二 任务3data_set\实验二 任务3data_set\sdkp1-10.txt')               # 返回一个文件对象   
    String=f2.read().strip().split('\n')
    for n in String:
        n.rstrip(',')
        n.rstrip('\n')
        n.rstrip('.')
        if n.startswith('*') or n.startswith('The') or n.startswith('SDKP') or n==' '  :
            continue
        else:
            data2.append(n[:-1])
    print(data2)
    f2.close()
    print("成功打开sdkp1-10.txt文件")
# Out:
# 欢迎来到D{0-1}背包问题！
# 请输入所需处理的文件名：idkp1-10
# 成功打开idkp1-10.txt文件
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams['font.family'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False  #负号显示的相关设置
# %matplotlib notebook
# %matplotlib inline

# %%
enter=input("进行绘图：请选择")
if(enter=1):
    fig = plt.figure()      #画布
    for i in range(0,len(data1)-1,2):
        x=list(map(int,data1[i].split(',')))
        y=list(map(int,data1[i+1].split(',')))
        plt.scatter(x,y)    #散点图函数
        plt.title("散点图")
        plt.xlabel('the X axis') 
        plt.ylabel('the Y axis')
        plt.show()
else
    fig = plt.figure()
    for i in range(0,len(data2)-1,2):
        x=list(map(int,data2[i].split(',')))
        y=list(map(int,data2[i+1].split(',')))
        plt.scatter(x,y)
        plt.title("散点图")
        plt.xlabel('the X axis') 
        plt.ylabel('the Y axis')
        plt.show()

# %%
#data1[0:2]
# Out:
# ['408,921,1329,11,998,1009,104,839,943,299,374,673,703,954,1657,425,950,1375,430,541,971,332,483,815,654,706,1360,956,992,1948',
#  '508,1021,1321,111,1098,1196,204,939,1107,399,474,719,803,1054,1781,525,1050,1362,530,641,903,432,583,894,754,806,1241,1056,1092,1545']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-56853f19d8bd> in <module>
# ----> 1 dp = [0 for _ in range(n+1)]
#       2 for i in range(1, len(n)+1):
#       3     for j in reversed(range(1, n+1)):
#       4         for k in range(3):
#       5             if j-n[i-1][k] >= 0:
#
# TypeError: can only concatenate str (not "int") to str
